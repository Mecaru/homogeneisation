# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x) :
    a = 1
    return 15*x/(7*a+8*x) - 9*x/(3*a+6*x)
F = np.vectorize(f)

X = np.linspace(0,1,100)
Y = F(X)
plt.plot(X,Y)
plt.show()
